# %%
class BinaryTree:
    def __init__(self,value):
        self.value =  value
        self.right =  right
        self.left =  left

# O(n)T and O(n)S
def branch_sums(root):
    sums = []
    running_sum = 0
    branch_sums_calculate(root, running_sum, sums)
    return sums

def branch_sums_calculate(node, running_sum, sums):
    if node is None:
        return None
    
    running_sum += node.value

    if node.left is None and node.right is None:
        sums.append(running_sum)

    # if node.left is not None:
    branch_sums_calculate(node.left, running_sum, sums)
    
    # if node.right is not None:
    branch_sums_calculate(node.right, running_sum, sums)
