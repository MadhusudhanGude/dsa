# %%
# O(N)T and O(n)S

class BST:
    def __init__(self, value, left=None, right=None):
        self.value = value
        self.left = left
        self.right = right

def tree_inorder_traversal(tree, array=[]):
    if tree is None:
        return

    tree_inorder_traversal(tree.left, array)
    array.append(tree.value)
    tree_inorder_traversal(tree.right, array)

    return array

def get_successor(tree, node):
    inorder_traversal = tree_inorder_traversal(tree)

    for idx, ele in enumerate(inorder_traversal):
        if ele != value:
            continue
        if idx == len(inorder_traversal)- 1:
            return None
        return inorder_traversal[idx+1]

# %%
# O(h)T and O(1)S

class BST:
    def __init__(self, value, left=None, right=None):
        self.value = value
        self.left = left
        self.right = right
        self.parent = parent


def find_successor(tree, node):
    if node.right is not None:
        return get_left_most_child(node.right)
    return get_right_most_parent(node)

def get_left_most_child(node):
    current_node = node
    while current_node.left != None:
        current_node = current_node.left
    
    return current_node


def get_right_most_parent(node):
    current_node = node
    while current_node.parent is not None and current_node == current_node.parent.right:
        current_node = current_node.parent
    return current_node
