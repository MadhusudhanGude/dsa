# %%
# O(nm* min(n, m))S and O(nm* min(n, m))T
def longest_common_subsequence(str1, str2):
    lcs = [[[] for x in range(len(str1) + 1)] for x in range(len(str2) + 1)]
    for i in range(1, len(str2) + 1):
        for j in range(1, len(str1) + 1):
            if str2[i-1] == str1[j-1]:
                lcs[i][j] = lcs[i-1][j-1] + [str2[i - 1]]
            else:
                lcs[i][j] = max(lcs[i-1][j], lcs[i][j-1], key=len)
    return lcs[-1][-1]

longest_common_subsequence('xkykzpw', 'zxvvyzw')
# Out:
# ['x', 'y', 'z', 'w']

# %%
# O(nm* min(n, m))S and O(nm* min(n, m))T
def longest_common_subsequence(str1, str2):
    lcs = [[[None, 0, None, None] for x in range(len(str1) + 1)] for x in range(len(str2) + 1)]
    for i in range(1, len(str2) + 1):
        for j in range(1, len(str1) + 1):
            if str2[i-1] == str1[j-1]:
                lcs[i][j] = [str2[i - 1], lcs[i - 1][j - 1][1] + 1, i - 1, j - 1]
            else:
                if lcs[i - 1][j][1] > lcs[i][j - 1][1]:
                    lcs[i][j] = [None, lcs[i - 1][j][1], i - 1, j]
                else:
                    lcs[i][j] = [None, lcs[i][j - 1][1], i, j - 1]
    
    # for each_row in lcs:
    #     print(each_row)
    return build_sequence(lcs)

def build_sequence(lcs):

    sequence = []
    i = len(lcs) - 1
    j = len(lcs[0]) - 1

    while i != 0 and j != 0:
        current_entry = lcs[i][j]
        if current_entry[0] is not None:
            sequence.append(current_entry[0])
        i = current_entry[2]
        j = current_entry[3]
        print(i, j)
    return list(reversed(sequence))

longest_common_subsequence('xkykzpw', 'zxvvyzw')
# Out:
# [[None, 0, None, None], [None, 0, None, None], [None, 0, None, None], [None, 0, None, None], [None, 0, None, None], [None, 0, None, None], [None, 0, None, None], [None, 0, None, None]]
# [[None, 0, None, None], [None, 0, 1, 0], ['x', 1, 0, 1], [None, 1, 1, 2], [None, 1, 1, 3], [None, 1, 1, 4], [None, 1, 1, 5], [None, 1, 1, 6]]
# [[None, 0, None, None], [None, 0, 2, 0], [None, 1, 1, 2], [None, 1, 2, 2], [None, 1, 2, 3], [None, 1, 2, 4], [None, 1, 2, 5], [None, 1, 2, 6]]
# [[None, 0, None, None], [None, 0, 3, 0], [None, 1, 2, 2], [None, 1, 3, 2], [None, 1, 3, 3], ['y', 2, 2, 4], [None, 2, 3, 5], [None, 2, 3, 6]]
# [[None, 0, None, None], [None, 0, 4, 0], [None, 1, 3, 2], [None, 1, 4, 2], [None, 1, 4, 3], [None, 2, 3, 5], [None, 2, 4, 5], [None, 2, 4, 6]]
# [[None, 0, None, None], ['z', 1, 4, 0], [None, 1, 5, 1], [None, 1, 5, 2], [None, 1, 5, 3], [None, 2, 4, 5], ['z', 3, 4, 5], [None, 3, 5, 6]]
# [[None, 0, None, None], [None, 1, 5, 1], [None, 1, 6, 1], [None, 1, 6, 2], [None, 1, 6, 3], [None, 2, 5, 5], [None, 3, 5, 6], [None, 3, 6, 6]]
# [[None, 0, None, None], [None, 1, 6, 1], [None, 1, 7, 1], [None, 1, 7, 2], [None, 1, 7, 3], [None, 2, 6, 5], [None, 3, 6, 6], ['w', 4, 6, 6]]
# 6 6
# 5 6
# 4 5
# 3 5
# 2 4
# 2 3
# 2 2
# 1 2
# 0 1
# ['x', 'y', 'z', 'w']

# %%
str1 = 0
str2 = 2
lcs = []
for i in range(1, len(str2) + 1):
    for j in range(1, len(str1) + 1):
        if str2[i-1] == str1[j-1]:
            lcs[i][j] = [str2[i - 1], lcs[i - 1][j - 1][1], i - 1, j - 1]
        else:
            if lcs[i - 1][j][1] > lcs[i][j - 1][1]:
                lcs[i][j] = [None, lcs[i - 1][j][1], i - 1, j]
            else:
                lcs[i][j] = [None, lcs[i][j - 1][1], i, j - 1]
