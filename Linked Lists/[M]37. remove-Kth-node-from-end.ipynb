# %%
class Node:
    def __init__(self, value, next=None):
        self.value = value
        self.next = next

class LinkedList:
    def __init__(self):
        self.head = None

    def remove_kth_node(self, n):
        # import pdb; pdb.set_trace()
        first = second = self.head
        i = 1
        while i<= n:
            second = second.next
            i +=1

        if second is None:
            first.value = first.next.value
            first.next = first.next.next
            return first

        while second.next is not None:
            second = second.next
            first = first.next
        
        first.next = first.next.next

        # return first

    def print_list(self):
        node = self.head

        while node is not None:
            print(node.value, end=' ')
            node = node.next


list = LinkedList()
list.head = Node(0,Node(1,Node(2,Node(3,Node(4,Node(5,Node(6,Node(7))))))) )
# list.head = Node(0)
# list.head.next = Node(1)
# list.head.next.next = Node(2)
# list.head.next.next.next = Node(3)
# list.head.next.next.next.next = Node(4)
# list.head.next.next.next.next.next = Node(5)
# list.head.next.next.next.next.next.next = Node(6)
# list.head.next.next.next.next.next.next.next = Node(7)

print('Elements before:')
list.print_list()
print()
list.remove_kth_node(3)
print('Elements after:')
list.print_list()
# Out:
# Elements before:
# 0 1 2 3 4 5 6 7
# Elements after:
# 0 1 2 3 4 6 7
