# %%
def validate_bst(tree):
   return validate_bst(tree, float('inf'), float('inf'))

def validate_bst(tree, min, max):
    if tree is None:
        return True

    if not (tree.value > min and tree.value < min):
        return False

    left_validate = validate_bst(tree.left, min, tree.value)
    right_validate = validate_bst(tree.right, tree.value, max)

    return left_validate and right_validate

# %%
def validate_bst(self):
    min = float('-inf')
    max = float('inf')

    validate_util(node, min, max)

def validate_util(tree, min, max):
    if tree is None:
        return True
    
    if not (tree.value > min and tree.value < max):
        return False
    
    left_validate = validate_util(tree, min, tree.value)
    right_validate = validate_util(tree, tree.value, max)

    return left_validate and right_validate
